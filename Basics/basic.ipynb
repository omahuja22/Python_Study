# %%
print("This is the Repository where I'll do all the python and the machine learning stuff")
# Out:
# This is the Repository where I'll do all the python and the machine learning stuff

# %%
a=10
b=20 
c=a+b
print(c)
# Out:
# 30

# %%
age=32
if age>30:
    
    print(age)
    
print(age)
# Out:
# 32
# 32

# %%
total=1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
